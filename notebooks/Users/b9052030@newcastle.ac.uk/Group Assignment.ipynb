><tr><td>1</td><td>1219</td><td>4.0</td><td>1094785994</td></tr><tr><td>1</td><td>1222</td><td>3.5</td><td>1112484637</td></tr><tr><td>1</td><td>1240</td><td>4.0</td><td>1112485401</td></tr><tr><td>1</td><td>1243</td><td>3.0</td><td>1112485567</td></tr><tr><td>1</td><td>1246</td><td>3.5</td><td>1094785759</td></tr><tr><td>1</td><td>1249</td><td>4.0</td><td>1112485382</td></tr><tr><td>1</td><td>1258</td><td>4.0</td><td>1094785994</td></tr><tr><td>1</td><td>1259</td><td>4.0</td><td>1112485440</td></tr><tr><td>1</td><td>1261</td><td>3.5</td><td>1094786113</td></tr><tr><td>1</td><td>1262</td><td>3.5</td><td>1112484735</td></tr><tr><td>1</td><td>1266</td><td>4.0</td><td>1112485371</td></tr><tr><td>1</td><td>1278</td><td>4.0</td><td>1094785986</td></tr><tr><td>1</td><td>1291</td><td>3.5</td><td>1112485525</td></tr><tr><td>1</td><td>1304</td><td>3.0</td><td>1094785720</td></tr><tr><td>1</td><td>1321</td><td>4.0</td><td>1094786062</td></tr><tr><td>1</td><td>1333</td><td>4.0</td><td>1112484990</td></tr><tr><td>1</td><td>1348</td><td>3.5</td><td>1094786056</td></tr><tr><td>1</td><td>1350</td><td>3.5</td><td>1094786158</td></tr><tr><td>1</td><td>1358</td><td>4.0</td><td>1112485419</td></tr><tr><td>1</td><td>1370</td><td>3.0</td><td>1094785764</td></tr><tr><td>1</td><td>1374</td><td>4.0</td><td>1094785746</td></tr><tr><td>1</td><td>1387</td><td>4.0</td><td>1112484913</td></tr><tr><td>1</td><td>1525</td><td>3.0</td><td>11124 ...

# %% [markdown]
# #### Average number of ratings per users

# %%
# To calculate the average number of ratings per user, the ratings dataframe is grouped by the userId and the entries per user counted. 
# In the next command the created dataframe with number of ratings per user is then used to calculate the average. 
from pyspark.sql.functions import avg
ratingsPerUser = ratings.select("userId", "rating").groupBy("userId").count()
ratingsPerUser.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-----+
# userId|count|
# +------+-----+
#  25649|   63|
#  25826|  204|
#  26486|   38|
#  26543|   28|
#  27255|   30|
# +------+-----+
# only showing top 5 rows
#
# </div>

# %%
ratingsPerUser.agg({"count": 'avg'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
#        avg(count)|
# +-----------------+
# 144.4135299257002|
# +-----------------+
#
# </div>

# %% [markdown]
# #### Average number of ratings per movie

# %%
# Calculating the average number of ratings per movie is similarly done to the average number of ratings per user, only that the ratings dataframe is this time grouped by the movieId. 
ratingsPerMovie = ratings.select("movieId", "rating").groupBy("movieId").count()
ratingsPerMovie.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----+
# movieId|count|
# +-------+-----+
#      29| 8520|
#    2529|12702|
#     474|18836|
#   45726| 1017|
#   60756| 1467|
# +-------+-----+
# only showing top 5 rows
#
# </div>

# %%
ratingsPerMovie.agg({"count": 'avg'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
#        avg(count)|
# +-----------------+
# 747.8411232425965|
# +-----------------+
#
# </div>

# %% [markdown]
# #### Histogram of the distribution of movie ratings per user

# %%
# Creating the two dataframes 'ratingsPerUser' and 'ratingsPerMovie' simplify the creation of a histogram showing the distribution of the ratings. 
display(ratingsPerUser)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th
</td></tr><tr><td>95149</td><td>55</td></tr><tr><td>60408</td><td>190</td></tr><tr><td>1697</td><td>22</td></tr><tr><td>40436</td><td>10</td></tr><tr><td>31156</td><td>85</td></tr><tr><td>91056</td><td>16</td></tr><tr><td>69720</td><td>12</td></tr><tr><td>89365</td><td>1</td></tr><tr><td>87992</td><td>12</td></tr><tr><td>91628</td><td>153</td></tr><tr><td>77947</td><td>5</td></tr><tr><td>92206</td><td>41</td></tr><tr><td>33760</td><td>44</td></tr><tr><td>84120</td><td>11</td></tr><tr><td>97216</td><td>8</td></tr><tr><td>74512</td><td>14</td></tr><tr><td>63676</td><td>55</td></tr><tr><td>74706</td><td>7</td></tr><tr><td>78606</td><td>12</td></tr><tr><td>86453</td><td>5</td></tr><tr><td>97699</td><td>9</td></tr><tr><td>92490</td><td>16</td></tr><tr><td>99893</td><td>1</td></tr><tr><td>89881</td><td>12</td></tr><tr><td>7279</td><td>18</td></tr><tr><td>91261</td><td>14</td></tr><tr><td>27919</td><td>7</td></tr><tr><td>55671</td><td>11</td></tr><tr><td>71936</td><td>11</td></tr><tr><td>48899</td><td>2</td></tr><tr><td>79035</td><td>9</td></tr><tr><td>102852</td><td>3</td></tr><tr><td>89041</td><td>1</td></tr><tr><td>93816</td><td>5</td></tr><tr><td>69299</td><td>9</td></tr><tr><td>131150</td><td>1</td></tr><tr><td>69708</td><td>3</td></tr><tr><td>88133</td><td>4</td></tr><tr><td>82097</td><td>6</td></tr><tr><td>115909</td><td>2</td></tr><tr><td>59861</td><td>2</td></tr><tr><td>58509</td><td>3</td></tr><tr><td>70593</td><td>3</td></tr><tr><td>86791</td><td>2</td></tr><tr><td>88228</td><td>2</td></tr><tr><td>96734</td><td>2</td></tr><tr><td>96923</td><td>3</td></tr><tr><td>112603</td><td>1</td></tr><tr><td>121025</td><td>1</td></tr><tr><td>118300</td><td>3</td></tr><tr><td>101583</td><td>3</td></tr><tr><td>86941</td><td>5</td></tr><tr><td>116185</td><td>1</td></tr><tr><td>54536</td><td>3</td></tr><tr><td>104498</td><td>2</td></tr><tr><td>103478</td><td>3</td></tr><tr><td>79106</td><td>1</td></tr><tr><td>54349</td><td>2</td></tr><tr><td>122127</td><td>1</td></tr><tr><td>126150</td><td>1</td></tr><tr><td>118528</td><td>1</td>< ...

# %% [markdown]
# # TASK 2

# %%
#loading necessary library
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import RegressionEvaluator
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Data Cleaning

# %%
# timestamp column is dropped as it will not be useful for the rest of analysis.
ratings = ratings.drop('timestamp')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Test Train split

# %%
# The data will be split into a trainning for the fit and a testing set for the evaulation later. A 50% 50% train and test split is used here as with the rest of the models used for this task.
(train, test) = ratings.randomSplit([0.50, 0.50], seed = 1234)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### ALS Construction

# %%
# The ALS is constructed by using the userIds to represent users, the movieIds to represent the items and the ratings column to represent the rating to fill.  Since the rating is not negative it, the non negative is True and preferences are not implicit. Also, a cold start strategy of drop is used to resolve the cold start problem (users with no reviews).

als = ALS(userCol="userId", itemCol="movieId", ratingCol="rating",
          nonnegative = True, implicitPrefs = False,
          coldStartStrategy = 'drop')

evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating", predictionCol="prediction")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Tuning Hyperparameters using Cross Validation

# %%
# By using k fold cross validation, we can compare ALS models using different hyper parameters to pick the ideal hyperparameters. For ALS, the parameters we will tune will be the rank & regParam which refers to the number of features to discover throughout the run.
# Grid
paramGrid = ParamGridBuilder() \
           .addGrid(als.rank, [10, 5, 1]) \
           .addGrid(als.regParam, [0.001,0.01,0.1])\
           .build()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Cross Validation and Best Model

# %%
cv = CrossValidator(
  estimator= als, estimatorParamMaps=paramGrid,
  evaluator=evaluator, numFolds=3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Running cross validation and choosing best model
cvmodel = cv.fit(train)
bestModel = cvmodel.bestModel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/ml/util.py:791: UserWarning: Can not find mlflow. To enable mlflow logging, install MLflow library from PyPi.
#   warnings.warn(_MLflowInstrumentation._NO_MLFLOW_WARNING)
# </div>

# %%
# Rank and regParam of model
print("rank: ", bestModel.rank, "\nregParam: ", bestModel._java_obj.parent().getRegParam())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: 10</div>

# %% [markdown]
# #### Best Model Results

# %%
predictions = bestModel.transform(test)
rmse = evaluator.evaluate(predictions)
print("Root-mean-square error = " + str(rmse))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0.8212424918487191
# </div>

# %%
display(predictions)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>movieId</th><th>rating</th><th>prediction</th></tr></thead><tbody><tr><td>53338</td><td>148</td><td>1.0</td><td>2.8997886</td></tr><tr><td>92852</td><td>148</td><td>3.0</td><td>2.69553</td></tr><tr><td>44979</td><td>148</td><td>3.0</td><td>2.9774113</td></tr><tr><td>1259</td><td>148</td><td>5.0</td><td>3.0970263</td></tr><tr><td>41389</td><td>148</td><td>3.0</td><td>3.5407796</td></tr><tr><td>60081</td><td>148</td><td>2.0</td><td>2.9708133</td></tr><tr><td>77165</td><td>148</td><td>3.0</td><td>2.6584544</td></tr><tr><td>59570</td><td>148</td><td>3.0</td><td>2.8659701</td></tr><tr><td>64843</td><td>148</td><td>3.5</td><td>2.7303085</td></tr><tr><td>101628</td><td>148</td><td>1.0</td><td>2.603192</td></tr><tr><td>81300</td><td>148</td><td>1.0</td><td>2.8528233</td></tr><tr><td>111523</td><td>148</td><td>2.0</td><td>3.155696</td></tr><tr><td>118205</td><td>148</td><td>3.5</td><td>2.7629712</td></tr><tr><td>28361</td><td>148</td><td>4.0</td><td>3.8020303</td></tr><tr><td>53715</td><td>148</td><td>4.0</td><td>3.1635208</td></tr><tr><td>36200</td><td>148</td><td>3.0</td><td>3.440279</td></tr><tr><td>117581</td><td>148</td><td>1.0</td><td>1.189156</td></tr><tr><td>67022</td><td>148</td><td>5.0</td><td>2.7644894</td></tr><tr><td>33736</td><td>148</td><td>2.5</td><td>2.3847647</td></tr><tr><td>109481</td><td>148</td><td>4.0</td><td>3.0792234</td></tr><tr><td>42069</td><td>148</td><td>3.0</td><td>2.5514452</td></tr><tr><td>80952</td><td>148</td><td>3.0</td><td>2.7880435</td></tr><tr><td>107346</td><td>148</td><td>3.0</td><td>2.400737</td></tr><tr><td>12126</td><td>148</td><td>1.0</td><td>2.51657</td></tr><tr><td>118112</td><td>148</td><td>1.0</td><td>2.495171</td></tr><tr><td>132550</td><td>148</td><td>4.0</td><td>2.7642293</td></tr><tr><td>57653</td><td>148</td><td>4.0</td><td>2.8823085</td></tr><tr><td>82418</td><td>148</td><td>3.0</td><td>2.8190808</td></tr><tr><td>83545</td><td>148</td><td>3.0</td><td>2.7373638</td></tr><tr><td>14388</td><td>148</td><td>2.0</td><td>2.8389227</td></tr><tr><td>490</td><td>148</td><td>3.0</td><td>2.938525</td></tr><tr><td>70139</td><td>148</td><td>1.0</td><td>2.5612893</td></tr><tr><td>3335</td><td>148</td><td>5.0</td><td>2.4968805</td></tr><tr><td>125585</td><td>148</td><td>4.0</td><td>2.832173</td></tr><tr><td>125753</td><td>148</td><td>2.0</td><td>2.602748</td></tr><tr><td>53993</td><td>148</td><td>4.0</td><td>3.6321654</td></tr><tr><td>13535</td><td>148</td><td>3.0</td><td>3.1437256</td></tr><tr><td>29229</td><td>148</td><td>3.0</td><td>3.0710351</td></tr><tr><td>46230</td><td>148</td><td>5.0</td><td>3.4460683</td></tr><tr><td>30387</td><td>148</td><td>1.0</td><td>3.0723996</td></tr><tr><td>136222</td><td>148</td><td>2.0</td><td>2.9190977</td></tr><tr><td>74757</td><td>148</td><td>3.5</td><td>2.7775345</td></tr><tr><td>19067</td><td>148</td><td>2.0</td><td>1.5771213</td></tr><tr><td>87301</td><td>148</td><td>2.0</td><td>2.2195108</td></tr><tr><td>108726</td><td>148</td><td>3.0</td><td>2.8732085</td></tr><tr><td>36821</td><td>148</td><td>4.0</td><td>2.6191397</td></tr><tr><td>97435</td><td>148</td><td>4.0</td><td>3.0115266</td></tr><tr><td>90757</td><td>148</td><td>3.0</td><td>3.1851807</td></tr><tr><td>125969</td><td>148</td><td>3.0</td><td>2.7287679</td></tr><tr><td>60334</td><td>148</td><td>4.0</td><td>3.0450342</td></tr><tr><td>96884</td><td>148</td><td>4.0</td><td>2.6060479</td></tr><tr><td>136453</td><td>148</td><td>2.0</td><td>2.8382144</td></tr><tr><td>3673</td><td>148</td><td>2.0</td><td>2.489407</td></tr><tr><td>36445</td><td>148</td><td>4.5</td><td>2.6018243</td></tr><tr><td>67743</td><td>148</td><td>3.0</td><td>2.7986627</td></tr><tr><td>78276</td><td>148</td><td>2.0</td><td>3.045858</td></tr><tr><td>108929</td><td>148</td><td>1.0</td><td>2.8263364</td></tr><tr><td>46944</td><td>148</td><td>2.0</td><td>2.929293</td></tr><tr><td>94994</td><td>148</td><td>4. ...

# %% [markdown]
# The model seems to quite well here considering the sparsity of the matrix, at least according to the root mean square error. However, perhaps the algorithm can be improved by feeding it's communities of users instead of the whole users datasets, where users of said communities are likely to have similar prefereneces and hence predicting ratings would be easier. This will be done using Girwan Newman in the remaining tasks.

# %% [markdown]
# # TASK 3

# %%
# Loading libraries
import pandas as pd
import pyspark.sql.functions as f
from pyspark.sql.types import *
from pyspark.sql import Row
from operator import add
from collections import Counter
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Taking 27000 users from the dataset
sampleUsers1 = ratings.select("userId").distinct().sample(fraction=0.2)
list = sampleUsers1.take(27000)
sampleUsers = spark.createDataFrame(list,['userId'])
sampleUsers.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: 27000</div>

# %%
# creating ratings_small file for parquet
from pyspark.sql.functions import when
ratings_small = ratings[ratings["userId"].isin(sampleUsers.toPandas()["userId"].tolist())]
ratings_small.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: 3889861</div>

# %%
#dbutils.fs.rm('small-rating.parquet', True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: True</div>

# %%
# saving ratings_small as parquet file. This won't work if file already exists.
ratings_small.write.parquet("ratings-small.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">     62</span>         <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">---&gt; 63</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">return</span> f<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">*</span>a<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">**</span>kw<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     64</span>         <span class="ansi-green-fg">except</span> py4j<span class="ansi-blue-fg">.</span>protocol<span class="ansi-blue-fg">.</span>Py4JJavaError <span class="ansi-green-fg">as</span> e<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py</span> in <span class="ansi-cyan-fg">get_return_value</span><span class="ansi-blue-fg">(answer, gateway_client, target_id, name)</span>
# <span class="ansi-green-intense-fg ansi-bold">    327</span>                     <span class="ansi-blue-fg">&#34;An error occurred while calling {0}{1}{2}.\n&#34;</span><span class="ansi-blue-fg">.</span>
# <span class="ansi-green-fg">--&gt; 328</span><span class="ansi-red-fg">                     format(target_id, &#34;.&#34;, name), value)
# </span><span class="ansi-green-intense-fg ansi-bold">    329</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">Py4JJavaError</span>: An error occurred while calling o27730.parquet.
# : org.apache.spark.sql.AnalysisException: path dbfs:/ratings-small.parquet already exists.;
# 	at org.apache.spark.sql.execution.datasources.InsertIntoHadoopFsRelationCommand.run(InsertIntoHadoopFsRelationCommand.scala:148)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult$lzycompute(commands.scala:108)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult(commands.scala:106)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.doExecute(commands.scala:126)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:146)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:134)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$5.apply(SparkPlan.scala:187)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:183)
# 	at org.apache.spark.sql.execution.SparkPlan.execute(SparkPlan.scala:134)
# 	at org.apache.spark.sql.execution.QueryExecution.toRdd$lzycompute(QueryExecution.scala:115)
# 	at org.apache.spark.sql.execution.QueryExecution.toRdd(QueryExecution.scala:115)
# 	at org.apache.spark.sql.DataFrameWriter$$anonfun$runCommand$1.apply(DataFrameWriter.scala:710)
# 	at org.apache.spark.sql.DataFrameWriter$$anonfun$runCommand$1.apply(DataFrameWriter.scala:710)
# 	at org.apache.spark.sql.execution.SQLExecution$$anonfun$withCustomExecutionEnv$1.apply(SQLExecution.scala:111)
# 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:240)
# 	at org.apache.spark.sql.execution.SQLExecution$.withCustomExecutionEnv(SQLExecution.scala:97)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:170)
# 	at org.apache.spark.sql.DataFrameWriter.runCommand(DataFrameWriter.scala:710)
# 	at org.apache.spark.sql.DataFrameWriter.saveToV1Source(DataFrameWriter.scala:306)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:292)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:235)
# 	at org.apache.spark.sql.DataFrameWriter.parquet(DataFrameWriter.scala:600)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:380)
# 	at py4j.Gateway.invoke(Gateway.java:295)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:251)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1004304869416591&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-red-fg"># saving ratings_small as parquet file</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>ratings_small<span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>parquet<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;ratings-small.parquet&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansi-cyan-fg">parquet</span><span class="ansi-blue-fg">(self, path, mode, partitionBy, compression)</span>
# <span class="ansi-green-intense-fg ansi-bold">    842</span>             self<span class="ansi-blue-fg">.</span>partitionBy<span class="ansi-blue-fg">(</span>partitionBy<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    843</span>         self<span class="ansi-blue-fg">.</span>_set_opts<span class="ansi-blue-fg">(</span>compression<span class="ansi-blue-fg">=</span>compression<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">--&gt; 844</span><span class="ansi-red-fg">         </span>self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>parquet<span class="ansi-blue-fg">(</span>path<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    845</span>
# <span class="ansi-green-intense-fg ansi-bold">    846</span>     <span class="ansi-blue-fg">@</span>since<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">1.6</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1255</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1256</span>         return_value = get_return_value(
# <span class="ansi-green-fg">-&gt; 1257</span><span class="ansi-red-fg">             answer, self.gateway_client, self.target_id, self.name)
# </span><span class="ansi-green-intense-fg ansi-bold">   1258</span>
# <span class="ansi-green-intense-fg ansi-bold">   1259</span>         <span class="ansi-green-fg">for

# %% [markdown]
# # TASK 4

# %%
# dropping 'timestamp' & 'rating' as they are not necessary for analysis for rest of the project.
ratings_small = ratings_small.drop('timestamp')
ratings_small = ratings_small.drop('rating')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Dataframes

# %%
# Two dataframes will be used to help divide the task up, each representing one of the user ids in the edge
ratings_small = spark.read.parquet("ratings-small.parquet")
df1 = ratings_small.select("movieId", "userId")
df2 = ratings_small.select("movieId", "userId").withColumnRenamed("movieId", "movieId2").withColumnRenamed("userId", "userId2")
UserMap = df1.join(df2, df1.movieId == df2.movieId2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
UserMap = UserMap.select("userId", "userId2")
UserMap.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+
# userId|userId2|
# +------+-------+
#  69144|  34375|
#  69144|  34364|
#  69144|  34357|
#  69144|  34350|
#  69144|  34337|
# +------+-------+
# only showing top 5 rows
#
# </div>

# %%
UserMap.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: 10177306061</div>

# %% [markdown]
# #### Edges

# %%
# finding duplicate edges
from pyspark.sql.functions import col, sum
edgesWithDuplicates = UserMap.groupBy(UserMap.columns).count().filter(UserMap.userId != UserMap.userId2)
edgesWithDuplicates.orderBy("count", ascending=False).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+-----+
# userId|userId2|count|
# +------+-------+-----+
#  88820| 125794| 2742|
# 125794|  88820| 2742|
#  71975| 125794| 2723|
# 125794|  71975| 2723|
# 125794| 130459| 2446|
# +------+-------+-----+
# only showing top 5 rows
#
# </div>

# %%
# total number of duplicate edges
edgesWithDuplicates.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: 638485306</div>

# %%
# Set User 1 to the smaller id and user2 to the larger id.... then remove duplicates
edgesRDD = edgesWithDuplicates.select("userId", "userId2", "count").rdd.map(lambda x: (min(x["userId"], x["userId2"]), max(x["userId"], x["userId2"]), x["count"]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
edges1 = spark.createDataFrame(edgesRDD, ["src", "dst", "count"])
edges = edges1.dropDuplicates()
edges.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: 319242653</div>

# %%
edges.agg({"count": 'avg'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
#        avg(count)|
# +-----------------+
# 15.93367899683505|
# +-----------------+
#
# </div>

# %%
# filtering the edges which are greater than average
edgesFiltered = edges.filter("count>15")
edgesFiltered.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: 90555467</div>

# %% [markdown]
# #### Vertices

# %%
verticesList = edgesFiltered.select("src").distinct().toPandas().values.tolist() + edgesFiltered.select("dst").distinct().toPandas().values.tolist()
verticesFiltered = spark.createDataFrame(verticesList, ["id"]).distinct()
verticesFiltered.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+
#     id|
# +------+
#  61135|
# 116612|
#  60882|
#  27469|
#  48899|
# +------+
# only showing top 5 rows
#
# </div>

# %%
verticesFiltered.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: 26968</div>

# %%
import os,sys
import pyspark.sql.functions as f
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from functools import reduce
from pyspark.sql.functions import col, lit, when
from graphframes import*
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Graph

# %%
# graph
graph = GraphFrame(verticesFiltered, edgesFiltered)
display(graph.edges)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3109666365315916&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-red-fg"># graph</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> graph <span class="ansi-blue-fg">=</span> GraphFrame<span class="ansi-blue-fg">(</span>verticesFiltered<span class="ansi-blue-fg">,</span> edgesFiltered<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg"> </span>graph<span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>parquet<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;graph.parquet&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> display<span class="ansi-blue-fg">(</span>graph<span class="ansi-blue-fg">.</span>edges<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">AttributeError</span>: &#39;GraphFrame&#39; object has no attribute &#39;write&#39;</div>

# %% [markdown]
# # TASK 5

# %%
sc.setCheckpointDir("dbfs:/tmp/group1/checkpoint")
# Computes the connected components of the graph.
connectedComp = graph.connectedComponents()  # DataFrame with new vertices column “component”
connectedComp.count()
display(connectedComp.sort("component", ascending = False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>component</th></tr></thead><tbody><tr><td>61135</td><td>3</td></tr><tr><td>116612</td><td>3</td></tr><tr><td>60882</td><td>3</td></tr><tr><td>27469</td><td>3</td></tr><tr><td>48899</td><td>3</td></tr><tr><td>15322</td><td>3</td></tr><tr><td>68463</td><td>3</td></tr><tr><td>92357</td><td>3</td></tr><tr><td>101756</td><td>3</td></tr><tr><td>102454</td><td>3</td></tr><tr><td>74114</td><td>3</td></tr><tr><td>48280</td><td>3</td></tr><tr><td>2214</td><td>3</td></tr><tr><td>7279</td><td>3</td></tr><tr><td>56242</td><td>3</td></tr><tr><td>9945</td><td>3</td></tr><tr><td>86445</td><td>3</td></tr><tr><td>52001</td><td>3</td></tr><tr><td>87992</td><td>3</td></tr><tr><td>92741</td><td>3</td></tr><tr><td>101221</td><td>3</td></tr><tr><td>35148</td><td>3</td></tr><tr><td>19141</td><td>3</td></tr><tr><td>30421</td><td>3</td></tr><tr><td>27255</td><td>3</td></tr><tr><td>83863</td><td>3</td></tr><tr><td>108247</td><td>3</td></tr><tr><td>67903</td><td>3</td></tr><tr><td>71097</td><td>3</td></tr><tr><td>69708</td><td>3</td></tr><tr><td>70095</td><td>3</td></tr><tr><td>54415</td><td>3</td></tr><tr><td>60033</td><td>3</td></tr><tr><td>55426</td><td>3</td></tr><tr><td>62693</td><td>3</td></tr><tr><td>65848</td><td>3</td></tr><tr><td>105657</td><td>3</td></tr><tr><td>39527</td><td>3</td></tr><tr><td>14117</td><td>3</td></tr><tr><td>101496</td><td>3</td></tr><tr><td>58877</td><td>3</td></tr><tr><td>75465</td><td>3</td></tr><tr><td>96359</td><td>3</td></tr><tr><td>102100</td><td>3</td></tr><tr><td>11276</td><td>3</td></tr><tr><td>11938</td><td>3</td></tr><t
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
src = edges.toPandas()["src"].tolist()
dst = edges.toPandas()["dst"].tolist()
edges_new = pd.DataFrame()
edges_new['src'] = src
edges_new['dst'] = dst
edges_new[['src','dst']]
G=nx.from_pandas_edgelist(edges_new,'src','dst')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# list all the nodes of the graph
G.number_of_nodes()
G.nodes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: NodeView((&#39;a&#39;, &#39;b&#39;, &#39;c&#39;, &#39;d&#39;, &#39;e&#39;, &#39;g&#39;, &#39;f&#39;))</div>

# %%
def _single_source_shortest_path_basic(G,s):
    S = [] # S is a dictionary. It stores the visited nodes
    P = {} # A dictionary to store parent node
    for v in G:
        P[v] = []
    sigma = dict.fromkeys(G, 0.0)    # sigma[v]=0 for v in G
                                    # set label for each node with 0 
    D = {}  #store the shortest path for each node to the begin node 
    sigma[s] = 1.0 # starting from vertex s and set the label of 1
    D[s] = 0 #initialise all the node to the begin node is 0
    Q = [s] # stack
    while Q:   # use BFS to find shortest paths
        v = Q.pop(0)
        S.append(v)
        Dv = D[v]
        sigmav = sigma[v]
        for w in G[v]:
            if w not in D:
                Q.append(w)
                D[w] = Dv + 1
                print("D[w] = ",w,D[w])
            if D[w] == Dv + 1:   # this is a shortest path, count paths
                sigma[w] += sigmav
                print("sigma[w] = ",w,sigma[w])
                P[w].append(v)  # predecessors
    print (S)
    print(P)
    print(sigma)
    return S, P, sigma
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def betweenness(G):
    betweenness = dict.fromkeys(G, 0.0)  # b[v]=0 for v in G
    # b[e]=0 for e in G.edges()
    betweenness.update(dict.fromkeys(G.edges(), 0.0))
    for s in G:
        # single source shortest paths
        # use BFS
        S, P, sigma = _single_source_shortest_path_basic(G,s)
        # accumulation
        betweenness = _accumulate_edges(betweenness, S, P, sigma, s)
    # rescaling
    for n in G:  # remove nodes to only return edges
        del betweenness[n]
    betweenness = _rescale_e(betweenness, len(G))
    return betweenness
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
betweenness(G)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">D[w] =  b 1
# sigma[w] =  b 1.0
# D[w] =  c 1
# sigma[w] =  c 1.0
# D[w] =  d 2
# sigma[w] =  d 1.0
# D[w] =  e 3
# sigma[w] =  e 1.0
# D[w] =  g 3
# sigma[w] =  g 1.0
# D[w] =  f 3
# sigma[w] =  f 1.0
# [&#39;a&#39;, &#39;b&#39;, &#39;c&#39;, &#39;d&#39;, &#39;e&#39;, &#39;g&#39;, &#39;f&#39;]
# {&#39;a&#39;: [], &#39;b&#39;: [&#39;a&#39;], &#39;c&#39;: [&#39;a&#39;], &#39;d&#39;: [&#39;b&#39;], &#39;e&#39;: [&#39;d&#39;], &#39;g&#39;: [&#39;d&#39;], &#39;f&#39;: [&#39;d&#39;]}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 1.0, &#39;e&#39;: 1.0, &#39;g&#39;: 1.0, &#39;f&#39;: 1.0}
# D[w] =  a 1
# sigma[w] =  a 1.0
# D[w] =  c 1
# sigma[w] =  c 1.0
# D[w] =  d 1
# sigma[w] =  d 1.0
# D[w] =  e 2
# sigma[w] =  e 1.0
# D[w] =  g 2
# sigma[w] =  g 1.0
# D[w] =  f 2
# sigma[w] =  f 1.0
# [&#39;b&#39;, &#39;a&#39;, &#39;c&#39;, &#39;d&#39;, &#39;e&#39;, &#39;g&#39;, &#39;f&#39;]
# {&#39;a&#39;: [&#39;b&#39;], &#39;b&#39;: [], &#39;c&#39;: [&#39;b&#39;], &#39;d&#39;: [&#39;b&#39;], &#39;e&#39;: [&#39;d&#39;], &#39;g&#39;: [&#39;d&#39;], &#39;f&#39;: [&#39;d&#39;]}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 1.0, &#39;e&#39;: 1.0, &#39;g&#39;: 1.0, &#39;f&#39;: 1.0}
# D[w] =  a 1
# sigma[w] =  a 1.0
# D[w] =  b 1
# sigma[w] =  b 1.0
# D[w] =  d 2
# sigma[w] =  d 1.0
# D[w] =  e 3
# sigma[w] =  e 1.0
# D[w] =  g 3
# sigma[w] =  g 1.0
# D[w] =  f 3
# sigma[w] =  f 1.0
# [&#39;c&#39;, &#39;a&#39;, &#39;b&#39;, &#39;d&#39;, &#39;e&#39;, &#39;g&#39;, &#39;f&#39;]
# {&#39;a&#39;: [&#39;c&#39;], &#39;b&#39;: [&#39;c&#39;], &#39;c&#39;: [], &#39;d&#39;: [&#39;b&#39;], &#39;e&#39;: [&#39;d&#39;], &#39;g&#39;: [&#39;d&#39;], &#39;f&#39;: [&#39;d&#39;]}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 1.0, &#39;e&#39;: 1.0, &#39;g&#39;: 1.0, &#39;f&#39;: 1.0}
# D[w] =  b 1
# sigma[w] =  b 1.0
# D[w] =  e 1
# sigma[w] =  e 1.0
# D[w] =  g 1
# sigma[w] =  g 1.0
# D[w] =  f 1
# sigma[w] =  f 1.0
# D[w] =  a 2
# sigma[w] =  a 1.0
# D[w] =  c 2
# sigma[w] =  c 1.0
# [&#39;d&#39;, &#39;b&#39;, &#39;e&#39;, &#39;g&#39;, &#39;f&#39;, &#39;a&#39;, &#39;c&#39;]
# {&#39;a&#39;: [&#39;b&#39;], &#39;b&#39;: [&#39;d&#39;], &#39;c&#39;: [&#39;b&#39;], &#39;d&#39;: [], &#39;e&#39;: [&#39;d&#39;], &#39;g&#39;: [&#39;d&#39;], &#39;f&#39;: [&#39;d&#39;]}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 1.0, &#39;e&#39;: 1.0, &#39;g&#39;: 1.0, &#39;f&#39;: 1.0}
# D[w] =  d 1
# sigma[w] =  d 1.0
# D[w] =  f 1
# sigma[w] =  f 1.0
# D[w] =  b 2
# sigma[w] =  b 1.0
# D[w] =  g 2
# sigma[w] =  g 1.0
# sigma[w] =  g 2.0
# D[w] =  a 3
# sigma[w] =  a 1.0
# D[w] =  c 3
# sigma[w] =  c 1.0
# [&#39;e&#39;, &#39;d&#39;, &#39;f&#39;, &#39;b&#39;, &#39;g&#39;, &#39;a&#39;, &#39;c&#39;]
# {&#39;a&#39;: [&#39;b&#39;], &#39;b&#39;: [&#39;d&#39;], &#39;c&#39;: [&#39;b&#39;], &#39;d&#39;: [&#39;e&#39;], &#39;e&#39;: [], &#39;g&#39;: [&#39;d&#39;, &#39;f&#39;], &#39;f&#39;: [&#39;e&#39;]}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 1.0, &#39;e&#39;: 1.0, &#39;g&#39;: 2.0, &#39;f&#39;: 1.0}
# D[w] =  d 1
# sigma[w] =  d 1.0
# D[w] =  f 1
# sigma[w] =  f 1.0
# D[w] =  b 2
# sigma[w] =  b 1.0
# D[w] =  e 2
# sigma[w] =  e 1.0
# sigma[w] =  e 2.0
# D[w] =  a 3
# sigma[w] =  a 1.0
# D[w] =  c 3
# sigma[w] =  c 1.0
# [&#39;g&#39;, &#39;d&#39;, &#39;f&#39;, &#39;b&#39;, &#39;e&#39;, &#39;a&#39;, &#39;c&#39;]
# {&#39;a&#39;: [&#39;b&#39;], &#39;b&#39;: [&#39;d&#39;], &#39;c&#39;: [&#39;b&#39;], &#39;d&#39;: [&#39;g&#39;], &#39;e&#39;: [&#39;d&#39;, &#39;f&#39;], &#39;g&#39;: [], &#39;f&#39;: [&#39;g&#39;]}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 1.0, &#39;e&#39;: 2.0, &#39;g&#39;: 1.0, &#39;f&#39;: 1.0}
# D[w] =  e 1
# sigma[w] =  e 1.0
# D[w] =  g 1
# sigma[w] =  g 1.0
# D[w] =  d 1
# sigma[w] =  d 1.0
# D[w] =  b 2
# sigma[w] =  b 1.0
# D[w] =  a 3
# sigma[w] =  a 1.0
# D[w] =  c 3
# sigma[w] =  c 1.0
# [&#39;f&#39;, &#39;e&#39;, &#39;g&#39;, &#39;d&#39;, &#39;b&#39;, &#39;a&#39;, &#39;c&#39;]
# {&#39;a&#39;: [&#39;b&#39;], &#39;b&#39;: [&#39;d&#39;], &#39;c&#39;: [&#39;b&#39;], &#39;d&#39;: [&#39;f&#39;], &#39;e&#39;: [&#39;f&#39;], &#39;g&#39;: [&#39;f&#39;], &#39;f&#39;: []}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 1.0, &#39;e&#39;: 1.0, &#39;g&#39;: 1.0, &#39;f&#39;: 1.0}
# Out[41]: {(&#39;a&#39;, &#39;b&#39;): 5.0,
#  (&#39;a&#39;, &#39;c&#39;): 1.0,
#  (&#39;b&#39;, &#39;c&#39;): 5.0,
#  (&#39;b&#39;, &#39;d&#39;): 12.0,
#  (&#39;d&#39;, &#39;e&#39;): 4.5,
#  (&#39;d&#39;, &#39;g&#39;): 4.5,
#  (&#39;d&#39;, &#39;f&#39;): 4.0,
#  (&#39;e&#39;, &#39;f&#39;): 1.5,
#  (&#39;g&#39;, &#39;f&#39;): 1.5}</div>

# %%
def _accumulate_edges(betweenness, S, P, sigma, s):
    delta = dict.fromkeys(S, 0)
    while S:
        w = S.pop()
        coeff = (1 + delta[w]) / sigma[w]
        for v in P[w]:
            c = sigma[v] * coeff
            if (v, w) not in betweenness:
                betweenness[(w, v)] += c
            else:
                betweenness[(v, w)] += c
            delta[v] += c
        if w != s:
            betweenness[w] += delta[w]
    return betweenness
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# rescaling
def _rescale_e(betweenness, n):
    scale = 0.5
      for v in betweenness:
         betweenness[v] *= scale
    return betweenness
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# compute the edge betweenness

def CmtyGirvanNewmanStep(G):
    init_ncomp = nx.number_connected_components(G)    #number of components
    ncomp = init_ncomp
    while ncomp <= init_ncomp:
        #return a dict betweenness as the value
#         bw = nx.edge_betweenness(G, weight='weight')    #edge betweenness for G 
        bw = betweenness(G)
        print("current betweenness of each edge")
        print(bw)
        #find the edge with max centrality
        max_ = max(bw.values())
        #find the edge with the highest centrality and remove all of them if there is more than one!
        for k, v in bw.items():
            if float(v) == max_:
                G.remove_edge(k[0],k[1])    #remove the central edge
        ncomp = nx.number_connected_components(G)    #recalculate the no of components
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# This method runs GirvanNewman algorithm and list communities as output after removing the top-K edges
def runGirvanNewman(G,k):
    while k>0:    
        CmtyGirvanNewmanStep(G)
        comps = list(nx.connected_components(G)) 
        print("communities:")
        print(comps)
        k = k-1
        if G.number_of_edges() == 0:
            break
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def main():
    runGirvanNewman(G,top_k)
if __name__ == "__main__":
      main()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">D[w] =  b 1
# sigma[w] =  b 1.0
# D[w] =  c 1
# sigma[w] =  c 1.0
# D[w] =  d 2
# sigma[w] =  d 1.0
# D[w] =  e 3
# sigma[w] =  e 1.0
# D[w] =  g 3
# sigma[w] =  g 1.0
# D[w] =  f 3
# sigma[w] =  f 1.0
# [&#39;a&#39;, &#39;b&#39;, &#39;c&#39;, &#39;d&#39;, &#39;e&#39;, &#39;g&#39;, &#39;f&#39;]
# {&#39;a&#39;: [], &#39;b&#39;: [&#39;a&#39;], &#39;c&#39;: [&#39;a&#39;], &#39;d&#39;: [&#39;b&#39;], &#39;e&#39;: [&#39;d&#39;], &#39;g&#39;: [&#39;d&#39;], &#39;f&#39;: [&#39;d&#39;]}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 1.0, &#39;e&#39;: 1.0, &#39;g&#39;: 1.0, &#39;f&#39;: 1.0}
# D[w] =  a 1
# sigma[w] =  a 1.0
# D[w] =  c 1
# sigma[w] =  c 1.0
# D[w] =  d 1
# sigma[w] =  d 1.0
# D[w] =  e 2
# sigma[w] =  e 1.0
# D[w] =  g 2
# sigma[w] =  g 1.0
# D[w] =  f 2
# sigma[w] =  f 1.0
# [&#39;b&#39;, &#39;a&#39;, &#39;c&#39;, &#39;d&#39;, &#39;e&#39;, &#39;g&#39;, &#39;f&#39;]
# {&#39;a&#39;: [&#39;b&#39;], &#39;b&#39;: [], &#39;c&#39;: [&#39;b&#39;], &#39;d&#39;: [&#39;b&#39;], &#39;e&#39;: [&#39;d&#39;], &#39;g&#39;: [&#39;d&#39;], &#39;f&#39;: [&#39;d&#39;]}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 1.0, &#39;e&#39;: 1.0, &#39;g&#39;: 1.0, &#39;f&#39;: 1.0}
# D[w] =  a 1
# sigma[w] =  a 1.0
# D[w] =  b 1
# sigma[w] =  b 1.0
# D[w] =  d 2
# sigma[w] =  d 1.0
# D[w] =  e 3
# sigma[w] =  e 1.0
# D[w] =  g 3
# sigma[w] =  g 1.0
# D[w] =  f 3
# sigma[w] =  f 1.0
# [&#39;c&#39;, &#39;a&#39;, &#39;b&#39;, &#39;d&#39;, &#39;e&#39;, &#39;g&#39;, &#39;f&#39;]
# {&#39;a&#39;: [&#39;c&#39;], &#39;b&#39;: [&#39;c&#39;], &#39;c&#39;: [], &#39;d&#39;: [&#39;b&#39;], &#39;e&#39;: [&#39;d&#39;], &#39;g&#39;: [&#39;d&#39;], &#39;f&#39;: [&#39;d&#39;]}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 1.0, &#39;e&#39;: 1.0, &#39;g&#39;: 1.0, &#39;f&#39;: 1.0}
# D[w] =  b 1
# sigma[w] =  b 1.0
# D[w] =  e 1
# sigma[w] =  e 1.0
# D[w] =  g 1
# sigma[w] =  g 1.0
# D[w] =  f 1
# sigma[w] =  f 1.0
# D[w] =  a 2
# sigma[w] =  a 1.0
# D[w] =  c 2
# sigma[w] =  c 1.0
# [&#39;d&#39;, &#39;b&#39;, &#39;e&#39;, &#39;g&#39;, &#39;f&#39;, &#39;a&#39;, &#39;c&#39;]
# {&#39;a&#39;: [&#39;b&#39;], &#39;b&#39;: [&#39;d&#39;], &#39;c&#39;: [&#39;b&#39;], &#39;d&#39;: [], &#39;e&#39;: [&#39;d&#39;], &#39;g&#39;: [&#39;d&#39;], &#39;f&#39;: [&#39;d&#39;]}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 1.0, &#39;e&#39;: 1.0, &#39;g&#39;: 1.0, &#39;f&#39;: 1.0}
# D[w] =  d 1
# sigma[w] =  d 1.0
# D[w] =  f 1
# sigma[w] =  f 1.0
# D[w] =  b 2
# sigma[w] =  b 1.0
# D[w] =  g 2
# sigma[w] =  g 1.0
# sigma[w] =  g 2.0
# D[w] =  a 3
# sigma[w] =  a 1.0
# D[w] =  c 3
# sigma[w] =  c 1.0
# [&#39;e&#39;, &#39;d&#39;, &#39;f&#39;, &#39;b&#39;, &#39;g&#39;, &#39;a&#39;, &#39;c&#39;]
# {&#39;a&#39;: [&#39;b&#39;], &#39;b&#39;: [&#39;d&#39;], &#39;c&#39;: [&#39;b&#39;], &#39;d&#39;: [&#39;e&#39;], &#39;e&#39;: [], &#39;g&#39;: [&#39;d&#39;, &#39;f&#39;], &#39;f&#39;: [&#39;e&#39;]}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 1.0, &#39;e&#39;: 1.0, &#39;g&#39;: 2.0, &#39;f&#39;: 1.0}
# D[w] =  d 1
# sigma[w] =  d 1.0
# D[w] =  f 1
# sigma[w] =  f 1.0
# D[w] =  b 2
# sigma[w] =  b 1.0
# D[w] =  e 2
# sigma[w] =  e 1.0
# sigma[w] =  e 2.0
# D[w] =  a 3
# sigma[w] =  a 1.0
# D[w] =  c 3
# sigma[w] =  c 1.0
# [&#39;g&#39;, &#39;d&#39;, &#39;f&#39;, &#39;b&#39;, &#39;e&#39;, &#39;a&#39;, &#39;c&#39;]
# {&#39;a&#39;: [&#39;b&#39;], &#39;b&#39;: [&#39;d&#39;], &#39;c&#39;: [&#39;b&#39;], &#39;d&#39;: [&#39;g&#39;], &#39;e&#39;: [&#39;d&#39;, &#39;f&#39;], &#39;g&#39;: [], &#39;f&#39;: [&#39;g&#39;]}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 1.0, &#39;e&#39;: 2.0, &#39;g&#39;: 1.0, &#39;f&#39;: 1.0}
# D[w] =  e 1
# sigma[w] =  e 1.0
# D[w] =  g 1
# sigma[w] =  g 1.0
# D[w] =  d 1
# sigma[w] =  d 1.0
# D[w] =  b 2
# sigma[w] =  b 1.0
# D[w] =  a 3
# sigma[w] =  a 1.0
# D[w] =  c 3
# sigma[w] =  c 1.0
# [&#39;f&#39;, &#39;e&#39;, &#39;g&#39;, &#39;d&#39;, &#39;b&#39;, &#39;a&#39;, &#39;c&#39;]
# {&#39;a&#39;: [&#39;b&#39;], &#39;b&#39;: [&#39;d&#39;], &#39;c&#39;: [&#39;b&#39;], &#39;d&#39;: [&#39;f&#39;], &#39;e&#39;: [&#39;f&#39;], &#39;g&#39;: [&#39;f&#39;], &#39;f&#39;: []}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 1.0, &#39;e&#39;: 1.0, &#39;g&#39;: 1.0, &#39;f&#39;: 1.0}
# current betweenness of each edge
# {(&#39;a&#39;, &#39;b&#39;): 5.0, (&#39;a&#39;, &#39;c&#39;): 1.0, (&#39;b&#39;, &#39;c&#39;): 5.0, (&#39;b&#39;, &#39;d&#39;): 12.0, (&#39;d&#39;, &#39;e&#39;): 4.5, (&#39;d&#39;, &#39;g&#39;): 4.5, (&#39;d&#39;, &#39;f&#39;): 4.0, (&#39;e&#39;, &#39;f&#39;): 1.5, (&#39;g&#39;, &#39;f&#39;): 1.5}
# communities:
# [{&#39;a&#39;, &#39;b&#39;, &#39;c&#39;}, {&#39;g&#39;, &#39;e&#39;, &#39;d&#39;, &#39;f&#39;}]
# D[w] =  b 1
# sigma[w] =  b 1.0
# D[w] =  c 1
# sigma[w] =  c 1.0
# [&#39;a&#39;, &#39;b&#39;, &#39;c&#39;]
# {&#39;a&#39;: [], &#39;b&#39;: [&#39;a&#39;], &#39;c&#39;: [&#39;a&#39;], &#39;d&#39;: [], &#39;e&#39;: [], &#39;g&#39;: [], &#39;f&#39;: []}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 0.0, &#39;e&#39;: 0.0, &#39;g&#39;: 0.0, &#39;f&#39;: 0.0}
# D[w] =  a 1
# sigma[w] =  a 1.0
# D[w] =  c 1
# sigma[w] =  c 1.0
# [&#39;b&#39;, &#39;a&#39;, &#39;c&#39;]
# {&#39;a&#39;: [&#39;b&#39;], &#39;b&#39;: [], &#39;c&#39;: [&#39;b&#39;], &#39;d&#39;: [], &#39;e&#39;: [], &#39;g&#39;: [], &#39;f&#39;: []}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 0.0, &#39;e&#39;: 0.0, &#39;g&#39;: 0.0, &#39;f&#39;: 0.0}
# D[w] =  a 1
# sigma[w] =  a 1.0
# D[w] =  b 1
# sigma[w] =  b 1.0
# [&#39;c&#39;, &#39;a&#39;, &#39;b&#39;]
# {&#39;a&#39;: [&#39;c&#39;], &#39;b&#39;: [&#39;c&#39;], &#39;c&#39;: [], &#39;d&#39;: [], &#39;e&#39;: [], &#39;g&#39;: [], &#39;f&#39;: []}
# {&#39;a&#39;: 1.0, &#39;b&#39;: 1.0, &#39;c&#39;: 1.0, &#39;d&#39;: 0.0, &#39;e&#39;: 0.0, &#39;g&#39;: 0.0, &#39;f&#39;: 0.0}
# D[w] =  e 1
# sigma[w] =  e 1.0
# D[w] =  g 1
# sigma[w] =  g 1.0
# D[w] =  f 1
# sigma[w] =  f 1.0
# [&#39;d&#39;, &#39;e&#39;, &#39;g&#39;, &#39;f&#39;]
# {&#39;a&#39;: [], &#39;b&#39;: [], &#39;c&#39;: [], &#39;d&#39;: [], &#39;e&#39;: [&#39;d&#39;], &#39;g&#39;: [&#39;d&#39;], &#39;f&#39;: [&#39;d&#39;]}
# {&#39;a&#39;: 0.0, &#39;b&#39;: 0.0, &#39;c&#39;: 0.0, &#39;d&#39;: 1.0, &#39;e&#39;: 1.0, &#39;g&#39;: 1.0, &#39;f&#39;: 1.0}
# D[w] =  d 1
# sigma[w] =  d 1.0
# D[w] =  f 1
# sigma[w] =  f 1.0
# D[w] =  g 2
# sigma[w] =  g 1.0
# sigma[w] =  g 2.0
# [&#39;e&#39;, &#39;d&#39;, &#39;f&#39;, &#39;g&#39;]
# {&#39;a&#39;: [], &#39;b&#39;: [], &#39;c&#39;: [], &#39;d&#39;: [&#39;e&#39;], &#39;e&#39;: [], &#39;g&#39;: [&#39;d&#39;, &#39;f&#39;], &#39;f&#39;: [&#39;e&#39;]}
# {&#39;a&#39;: 0.0, &#39;b&#39;: 0.0, &#39;c&#39;: 0.0, &#39;d&#39;: 1.0, &#39;e&#39;: 1.0, &#39;g&#39;: 2.0, &#39;f&#39;: 1.0}
# D[w] =  d 1
# sigma[w] =  d 1.0
# D[w] =  f 1
# sigma[w] =  f 1.0
# D[w] =  e 2
# sigma[w] =  e 1.0
# sigma[w] =  e 2.0
# [&#39;g&#39;, &#39;d&#39;, &#39;f&#39;, &#39;e&#39;]
# {&#39;a&#39;: [], &#39;b&#39;: [], &#39;c&#39;: [], &#39;d&#39;: [&#39;g&#39;], &#39;e&#39;: [&#39;d&#39;, &#39;f&#39;], &#39;g&#39;: [], &#39;f&#39;: [&#39;g&#39;]}
# {&#39;a&#39;: 0.0, &#39;b&#39;: 0.0, &#39;c&#39;: 0.0, &#39;d&#39;: 1.0, &#39;e&#39;: 2.0, &#39;g&#39;: 1.0, &#39;f&#39;: 1.0}
# D[w] =  e 1
# sigma[w] =  e 1.0
# D[w] =  g 1
# sigma[w] =  g 1.0
# D[w] =  d 1
# sigma[w] =  d 1.0
# [&#39;f&#39;, &#39;e&#39;, &#39;g&#39;, &#39;d&#39;]
# {&#39;a&#39;: [], &#39;b&#39;: [], &#39;c&#39;: [], &#39;d&#39;: [&#39;f&#39;], &#39;e&#39;: [&#39;f&#39;], &#39;g&#39;: [&#39;f&#39;], &#39;f&#39;: []}
# {&#39;a&#39;: 0.0, &#39;b&#39;: 0.0, &#39;c&#39;: 0.0, &#39;d&#39;: 1.0, &#39;e&#39;: 1.0, &#39;g&#39;: 1.0, &#39;f&#39;: 1.0}
# current betweenness of each edge
# {(&#39;a&#39;, &#39;b&#39;): 1.0, (&#39;a&#39;, &#39;c&#39;): 1.0, (&#39;b&#39;, &#39;c&#39;): 1.0, (&#39;d&#39;, &#39;e&#39;): 1.5, (&#39;d&#39;, &#39;g&#39;): 1.5, (&#39;d&#39;,

# %% [markdown]
# ##Girvan-Newman algorithm for subgraph

# %%
#create networkx graph
subG = spark.read.parquet("edges_max_component.parquet")
sub_src = subG.toPandas()["src"].tolist()
sub_dst = subG.toPandas()["dst"].tolist()
edges_sub = pd.DataFrame()
edges_sub['src'] = sub_src
edges_sub['dst'] = sub_dst
edges_sub[['src','dst']]
sub_G=nx.from_pandas_edgelist(edges_sub,'src','dst')

# %%
runGirvanNewman(sub_G,top_k)
